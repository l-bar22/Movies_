# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import requests
import json
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
data=pd.read_csv('../movies/Movie_Data.csv' , encoding='1252')
data.head(10)
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
data.shape
# Out:
# (1000, 12)

# %%
data.info
# Out:
# <bound method DataFrame.info of      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
data.dtypes
# Out:
# Rank                    int64
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object

# %%
data.isnull().values.any()
# Out:
# True

# %%
data.isnull().sum().sum()
# Out:
# 192

# %%
data.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data1=data[['Genre','Director','Title','Year','Rating','Revenue (Millions)']]
data1
# Out:
#                         Genre              Director                    Title  \
# 0     Action,Adventure,Sci-Fi            James Gunn  Guardians of the Galaxy
# 1    Adventure,Mystery,Sci-Fi          Ridley Scott               Prometheus
# 2             Horror,Thriller    M. Night Shyamalan                    Split
# 3     Animation,Comedy,Family  Christophe Lourdelet                     Sing
# 4    Action,Adventure,Fantasy            David Ayer            Suicide Squad
# ..                        ...                   ...                      ...
# 995       Crime,Drama,Mystery             Billy Ray     Secret in Their Eyes
# 996                    Horror              Eli Roth          Hostel: Part II
# 997       Drama,Music,Romance            Jon M. Chu   Step Up 2: The Streets
# 998          Adventure,Comedy        Scot Armstrong             Search Party
# 999     Comedy,Family,Fantasy      Barry Sonnenfeld               Nine Lives
#
#      Year  Rating  Revenue (Millions)
# ...

# %%
data1=data1.rename(columns = {'Revenue (Millions)':'Revenue(M$)'})
data1
# Out:
#                         Genre              Director                    Title  \
# 0     Action,Adventure,Sci-Fi            James Gunn  Guardians of the Galaxy
# 1    Adventure,Mystery,Sci-Fi          Ridley Scott               Prometheus
# 2             Horror,Thriller    M. Night Shyamalan                    Split
# 3     Animation,Comedy,Family  Christophe Lourdelet                     Sing
# 4    Action,Adventure,Fantasy            David Ayer            Suicide Squad
# ..                        ...                   ...                      ...
# 995       Crime,Drama,Mystery             Billy Ray     Secret in Their Eyes
# 996                    Horror              Eli Roth          Hostel: Part II
# 997       Drama,Music,Romance            Jon M. Chu   Step Up 2: The Streets
# 998          Adventure,Comedy        Scot Armstrong             Search Party
# 999     Comedy,Family,Fantasy      Barry Sonnenfeld               Nine Lives
#
#      Year  Rating  Revenue(M$)
# ...

# %%
data1['Revenue(M$)'].fillna(0, inplace=True)
data1
# Out:
#                         Genre              Director                    Title  \
# 0     Action,Adventure,Sci-Fi            James Gunn  Guardians of the Galaxy
# 1    Adventure,Mystery,Sci-Fi          Ridley Scott               Prometheus
# 2             Horror,Thriller    M. Night Shyamalan                    Split
# 3     Animation,Comedy,Family  Christophe Lourdelet                     Sing
# 4    Action,Adventure,Fantasy            David Ayer            Suicide Squad
# ..                        ...                   ...                      ...
# 995       Crime,Drama,Mystery             Billy Ray     Secret in Their Eyes
# 996                    Horror              Eli Roth          Hostel: Part II
# 997       Drama,Music,Romance            Jon M. Chu   Step Up 2: The Streets
# 998          Adventure,Comedy        Scot Armstrong             Search Party
# 999     Comedy,Family,Fantasy      Barry Sonnenfeld               Nine Lives
#
#      Year  Rating  Revenue(M$)
# ...

# %%
data1.sort_values(by=['Year'], ascending=False,inplace=True)
data1
# Out:
#                        Genre               Director  \
# 999    Comedy,Family,Fantasy       Barry Sonnenfeld
# 161      Action,Comedy,Crime           Ben Wheatley
# 647  Fantasy,Horror,Thriller      Jonathan Holbrook
# 234   Action,Adventure,Drama  Cedric Nicolas-Troyan
# 653             Comedy,Music         Akiva Schaffer
# ..                       ...                    ...
# 715  Animation,Comedy,Family          George Miller
# 727    Drama,Mystery,Romance            Neil Burger
# 965   Drama,Mystery,Thriller            David Lynch
# 559  Adventure,Comedy,Sci-Fi             Mike Judge
# 230        Drama,Fantasy,War     Guillermo del Toro
#
#                                   Title  Year  Rating  Revenue(M$)
# 999                          Nine Lives  2016     5.3        19.64
# 161                           Free Fire  2016     7.0         1.80
# 647                            Tall Men  2016     3.2         0.00
# 234          The Huntsman: Winter's War  2016     6.1        47.95
# ...

# %%
data2=data1.set_index('Year')
data2
# Out:
#                         Genre               Director  \
# Year
# 2016    Comedy,Family,Fantasy       Barry Sonnenfeld
# 2016      Action,Comedy,Crime           Ben Wheatley
# 2016  Fantasy,Horror,Thriller      Jonathan Holbrook
# 2016   Action,Adventure,Drama  Cedric Nicolas-Troyan
# 2016             Comedy,Music         Akiva Schaffer
# ...                       ...                    ...
# 2006  Animation,Comedy,Family          George Miller
# 2006    Drama,Mystery,Romance            Neil Burger
# 2006   Drama,Mystery,Thriller            David Lynch
# 2006  Adventure,Comedy,Sci-Fi             Mike Judge
# 2006        Drama,Fantasy,War     Guillermo del Toro
#
#                                    Title  Rating  Revenue(M$)
# Year
# 2016                          Nine Lives     5.3        19.64
# 2016                           Free Fire     7.0         1.80
# 2016                            Tall Men     3.2         0.00
# 2016          The Huntsman: Winter's War     6.1        47.95
# ...

# %%
data2.sort_values(by=['Rating'], ascending=False,inplace=True)
data2.head(10)
# Out:
#                         Genre                          Director  \
# Year
# 2008       Action,Crime,Drama                 Christopher Nolan
# 2016   Action,Biography,Drama                     Nitesh Tiwari
# 2010  Action,Adventure,Sci-Fi                 Christopher Nolan
# 2014   Adventure,Drama,Sci-Fi                 Christopher Nolan
# 2011   Biography,Comedy,Drama                   Olivier Nakache
# 2016  Animation,Drama,Fantasy                    Makoto Shinkai
# 2014              Drama,Music                   Damien Chazelle
# 2006           Drama,Thriller  Florian Henckel von Donnersmarck
# 2012          Action,Thriller                 Christopher Nolan
# 2006     Drama,Mystery,Sci-Fi                 Christopher Nolan
#
#                       Title  Rating  Revenue(M$)
# Year
# 2008        The Dark Knight     9.0       533.32
# 2016                 Dangal     8.8        11.15
# 2010              Inception     8.8       292.57
# 2014           Interstellar     8.6       187.99
# ...

# %%
url = "https://imdb8.p.rapidapi.com"
response = requests.get(url)
response
# Out:
# <Response [401]>

# %% [markdown]
# He probado con estas tres combinaciones diferentes y ninguna ha funcionado así que finalmente he optado por utilizar el token de forma visible ejecutar el código,borrarlo después y subirlo ya borrado a github.

# %% [markdown]
# def getFromRAPI(endpoint, queryParams={}):
#     url = f"https://imdb8.p.rapidapi.com{endpoint}"
#     querystring = {"tconst":"tt0944947"}
#     apiKey = os.getenv("RAPIKEY")
#     if not apiKey:
#         raise ValueError("Please setup the RAPIKEY env variable")
#     headers = {
#         'x-rapidapi-host': "imdb8.p.rapidapi.com"
#         'Authorization' : f"token {apiKey}"
#     }
#
#     res = requests.get(url, headers=headers, params=querystring)
#     print(res.url)
#     return res.json()

# %% [markdown]
# url = "https://imdb8.p.rapidapi.com/title/get-top-cast"
#
# querystring = {"tconst":"tt0944947"}
# apiKey = os.getenv("RAPIKEY")
# headers = {
#     'x-rapidapi-host': "imdb8.p.rapidapi.com",
#     'x-rapidapi-key': f"token{apiKey}"
#     }
#
# response = requests.request("GET", url, headers=headers, params=querystring)
#
# print(response.text)

# %% [markdown]
# import requests
#
# url = "https://imdb8.p.rapidapi.com/title/get-top-cast"
#
# querystring = {"tconst":"tt0944947"}
#
# headers = {
#     'x-rapidapi-host': "imdb8.p.rapidapi.com",
#     'x-rapidapi-key': ""
#     }
#
# response = requests.request("GET", url, headers=headers, params=querystring)
#
# print(response.text)

# %%
import requests

url = "https://imdb8.p.rapidapi.com/title/get-versions"

querystring = {"tconst":"tt0944947"}

headers = {
    'x-rapidapi-host': "imdb8.p.rapidapi.com",
    'x-rapidapi-key': ""
    }

response = requests.request("GET", url, headers=headers, params=querystring)

response.text
d=response.json()
d
# Out:
# {'@type': 'imdb.api.title.versions',
#  'alternateTitles': [{'region': 'SI',
#    'title': 'Igra prestolov',
#    'types': ['imdbDisplay']},
#   {'region': 'US', 'title': 'A Song of Ice and Fire', 'types': ['working']},
#   {'region': 'LT', 'title': 'Sostų karai', 'types': ['imdbDisplay']},
#   {'attributes': ['literal title'],
#    'language': 'fa',
#    'region': 'IR',
#    'title': 'Baziye tajo takht'},
#   {'region': 'RO', 'title': 'Urzeala tronurilor', 'types': ['imdbDisplay']},
#   {'title': 'Game of Thrones', 'types': ['original']},
#   {'language': 'hi',
#    'region': 'IN',
#    'title': 'Game of Thrones',
#    'types': ['imdbDisplay']},
#   {'attributes': ['DVD box title'],
#    'region': 'FR',
#    'title': 'Game of Thrones - Le trône de fer'},
#   {'region': 'AU', 'title': 'Game of Thrones', 'types': ['imdbDisplay']},
#   {'language': 'tr',
#    'region': 'TR',
#    'title': 'Taht Oyunları',
#    'types': ['imdbDisplay']},
# ...

# %%
import requests

url = "https://imdb8.p.rapidapi.com/title/get-parental-guide"

querystring = {"tconst":"tt0120338"}

headers = {
    'x-rapidapi-host': "imdb8.p.rapidapi.com",
    'x-rapidapi-key': ""
    }

response = requests.request("GET", url, headers=headers, params=querystring)

response.text
t=response.json()
t
# Out:
# {'parentalguide': [{'items': [{'hasProfanity': False,
#      'id': '/title/tt0120338/parentalguide/pg0488374',
#      'isSpoiler': False,
#      'language': 'eng',
#      'text': "Jack and Rose run inside a car. Rose kisses Jack's fingers. She puts his hand on her breast before having sex. They have sex (offscreen)."},
#     {'hasProfanity': False,
#      'id': '/title/tt0120338/parentalguide/pg0595712',
#      'isSpoiler': False,
#      'language': 'eng',
#      'text': 'One female frontal naked body scene at about 20 seconds but there are no sexual activity.'},
#     {'hasProfanity': False,
#      'id': '/title/tt0120338/parentalguide/pg0664459',
#      'isSpoiler': False,
#      'language': 'eng',
#      'text': 'Some kissing scenes between the main characters.'},
#     {'hasProfanity': True,
#      'id': '/title/tt0120338/parentalguide/pg0678472',
#      'isSpoiler': False,
#      'language': 'eng',
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-a9c4ad87fe81> in <module>
# ----> 1 dt=d+t
#       2 dt
#
# TypeError: can only concatenate list (not "dict") to list

# %%
import requests

url = "https://imdb8.p.rapidapi.com/title/get-awards-summary"

querystring = {"tconst":"tt0944947"}

headers = {
    'x-rapidapi-host': "imdb8.p.rapidapi.com",
    'x-rapidapi-key': ""
    }

response = requests.request("GET", url, headers=headers, params=querystring)

response.text
a=response.json()
a
# Out:
# {'@type': 'imdb.api.title.awardssummary',
#  'awardsSummary': {'highlighted': {'awardName': 'Golden Globe',
#    'count': 1,
#    'eventId': '/event/ev0000292/',
#    'isWinner': True},
#   'otherNominationsCount': 604,
#   'otherWinsCount': 374},
#  'highlightedRanking': {'id': '/chart/ratings/toptv',
#   'label': 'Top 250 TV',
#   'rank': 10,
#   'rankType': 'topTv'},
#  'id': '/title/tt0944947/',
#  'title': 'Game of Thrones',
#  'titleType': 'tvSeries',
#  'year': 2011}

# %%
import requests

url = "https://imdb8.p.rapidapi.com/title/get-filming-locations"

querystring = {"tconst":"tt0944947"}

headers = {
    'x-rapidapi-host': "imdb8.p.rapidapi.com",
    'x-rapidapi-key': ""
    }

response = requests.request("GET", url, headers=headers, params=querystring)

response.text
s=response.json()
s
# Out:
# {'@type': 'imdb.api.title.filminglocations',
#  'base': {'id': '/title/tt0944947/',
#   'image': {'height': 1500,
#    'id': '/title/tt0944947/images/rm4204167425',
#    'url': 'https://m.media-amazon.com/images/M/MV5BYTRiNDQwYzAtMzVlZS00NTI5LWJjYjUtMzkwNTUzMWMxZTllXkEyXkFqcGdeQXVyNDIzMzcwNjc@._V1_.jpg',
#    'width': 1102},
#   'runningTimeInMinutes': 57,
#   'nextEpisode': '/title/tt1480055/',
#   'numberOfEpisodes': 73,
#   'seriesEndYear': 2019,
#   'seriesStartYear': 2011,
#   'title': 'Game of Thrones',
#   'titleType': 'tvSeries',
#   'year': 2011},
#  'id': '/title/tt0944947/',
#  'locations': [{'id': '/title/tt0944947/filminglocations/lc0820830',
#    'interestingVotes': {'down': 10, 'up': 356},
#    'location': 'Split, Split-Dalmatia County, Croatia'},
#   {'id': '/title/tt0944947/filminglocations/lc0820831',
#    'interestingVotes': {'down': 8, 'up': 210},
#    'location': 'Vrsno, Sibenik, Croatia'},
#   {'id': '/title/tt0944947/filminglocations/lc0449596',
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-12f48bbc4a2d> in <module>
# ----> 1 d.update(t)
#       2 d
#
# AttributeError: 'list' object has no attribute 'update'
