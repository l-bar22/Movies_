# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('../movies/Movie_Data.csv' , encoding='1252')
data.head(10)
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
data.shape
# Out:
# (1000, 12)

# %%
data.info
# Out:
# <bound method DataFrame.info of      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
data.dtypes
# Out:
# Rank                    int64
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object

# %%
data.isnull().values.any()
# Out:
# True

# %%
data.isnull().sum().sum()
# Out:
# 192

# %%
data.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
data1=data[['Genre','Director','Actors','Year','Rating','Revenue (Millions)']]
data1
# Out:
#                         Genre              Director  \
# 0     Action,Adventure,Sci-Fi            James Gunn
# 1    Adventure,Mystery,Sci-Fi          Ridley Scott
# 2             Horror,Thriller    M. Night Shyamalan
# 3     Animation,Comedy,Family  Christophe Lourdelet
# 4    Action,Adventure,Fantasy            David Ayer
# ..                        ...                   ...
# 995       Crime,Drama,Mystery             Billy Ray
# 996                    Horror              Eli Roth
# 997       Drama,Music,Romance            Jon M. Chu
# 998          Adventure,Comedy        Scot Armstrong
# 999     Comedy,Family,Fantasy      Barry Sonnenfeld
#
#                                                 Actors  Year  Rating  \
# 0    Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014     8.1
# 1    Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012     7.0
# 2    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016     7.3
# ...

# %%
data1=data1.rename(columns = {'Revenue (Millions)':'Revenue(M$)'})
data1
# Out:
#                         Genre              Director  \
# 0     Action,Adventure,Sci-Fi            James Gunn
# 1    Adventure,Mystery,Sci-Fi          Ridley Scott
# 2             Horror,Thriller    M. Night Shyamalan
# 3     Animation,Comedy,Family  Christophe Lourdelet
# 4    Action,Adventure,Fantasy            David Ayer
# ..                        ...                   ...
# 995       Crime,Drama,Mystery             Billy Ray
# 996                    Horror              Eli Roth
# 997       Drama,Music,Romance            Jon M. Chu
# 998          Adventure,Comedy        Scot Armstrong
# 999     Comedy,Family,Fantasy      Barry Sonnenfeld
#
#                                                 Actors  Year  Rating  \
# 0    Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014     8.1
# 1    Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012     7.0
# 2    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016     7.3
# ...

# %%
data1['Revenue(M$)'].fillna(0, inplace=True)
data1
# Out:
#                         Genre              Director  \
# 0     Action,Adventure,Sci-Fi            James Gunn
# 1    Adventure,Mystery,Sci-Fi          Ridley Scott
# 2             Horror,Thriller    M. Night Shyamalan
# 3     Animation,Comedy,Family  Christophe Lourdelet
# 4    Action,Adventure,Fantasy            David Ayer
# ..                        ...                   ...
# 995       Crime,Drama,Mystery             Billy Ray
# 996                    Horror              Eli Roth
# 997       Drama,Music,Romance            Jon M. Chu
# 998          Adventure,Comedy        Scot Armstrong
# 999     Comedy,Family,Fantasy      Barry Sonnenfeld
#
#                                                 Actors  Year  Rating  \
# 0    Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014     8.1
# 1    Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012     7.0
# 2    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016     7.3
# ...

# %%
data1.sort_values(by=['Year'], ascending=False)
# Out:
#                        Genre               Director  \
# 999    Comedy,Family,Fantasy       Barry Sonnenfeld
# 161      Action,Comedy,Crime           Ben Wheatley
# 647  Fantasy,Horror,Thriller      Jonathan Holbrook
# 234   Action,Adventure,Drama  Cedric Nicolas-Troyan
# 653             Comedy,Music         Akiva Schaffer
# ..                       ...                    ...
# 715  Animation,Comedy,Family          George Miller
# 727    Drama,Mystery,Romance            Neil Burger
# 965   Drama,Mystery,Thriller            David Lynch
# 559  Adventure,Comedy,Sci-Fi             Mike Judge
# 230        Drama,Fantasy,War     Guillermo del Toro
#
#                                                 Actors  Year  Rating  \
# 999  Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...  2016     5.3
# 161  Sharlto Copley, Brie Larson, Armie Hammer, Cil...  2016     7.0
# 647  Dan Crisafulli, Kay Whitney, Richard Garcia, P...  2016     3.2
# ...

# %%
foo = lambda x: pd.Series([i for i in reversed(x.split(','))])
rev = data['Actors'].apply(foo)
rev.rename(columns={0:'Act1',1:'Act2',2:'Act3',3:'Act4'},inplace=True)
rev
# Out:
#                     Act1                  Act2                   Act3  \
# 0            Zoe Saldana        Bradley Cooper             Vin Diesel
# 1        Charlize Theron    Michael Fassbender   Logan Marshall-Green
# 2           Jessica Sula   Haley Lu Richardson        Anya Taylor-Joy
# 3     Scarlett Johansson       Seth MacFarlane      Reese Witherspoon
# 4            Viola Davis         Margot Robbie             Jared Leto
# ..                   ...                   ...                    ...
# 995          Dean Norris         Julia Roberts          Nicole Kidman
# 996           Roger Bart        Bijou Phillips      Heather Matarazzo
# 997       Adam G. Sevani        Cassie Ventura          Briana Evigan
# 998     Shannon Woodward    Thomas Middleditch            T.J. Miller
# 999         Cheryl Hines          Robbie Amell        Jennifer Garner
#
#                     Act4
# 0            Chris Pratt
# 1           Noomi Rapace
# 2           James McAvoy
# ...

# %%
# Out:
#                         Genre              Director  \
# 0     Action,Adventure,Sci-Fi            James Gunn
# 1    Adventure,Mystery,Sci-Fi          Ridley Scott
# 2             Horror,Thriller    M. Night Shyamalan
# 3     Animation,Comedy,Family  Christophe Lourdelet
# 4    Action,Adventure,Fantasy            David Ayer
# ..                        ...                   ...
# 995       Crime,Drama,Mystery             Billy Ray
# 996                    Horror              Eli Roth
# 997       Drama,Music,Romance            Jon M. Chu
# 998          Adventure,Comedy        Scot Armstrong
# 999     Comedy,Family,Fantasy      Barry Sonnenfeld
#
#                                                 Actors  Year  Rating  \
# 0    Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...  2014     8.1
# 1    Noomi Rapace, Logan Marshall-Green, Michael Fa...  2012     7.0
# 2    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...  2016     7.3
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-0e88146c3cb5> in <module>
#       1 foo = lambda x: pd.Series([i for i in reversed(x.split(','))])
# ----> 2 rev = df['Actors'].apply(foo)
#       3 rev.rename(columns={0:'Act1',1:'Act2',2:'Act3',3:'Act4'},inplace=True)
#       4 rev
#
# NameError: name 'df' is not defined
